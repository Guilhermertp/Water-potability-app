# %%
pip freeze
# Out:
# - @ file:///C:/ci/scikit-learn_1598377018496/work
# -.ikit-learn @ file:///C:/ci/scikit-learn_1598377018496/work
# -0ikit-learn @ file:///C:/ci/scikit-learn_1598377018496/work
# -cikit-learn @ file:///C:/ci/scikit-learn_1598377018496/work
# absl-py==0.13.0
# alabaster==0.7.12
# alembic==1.4.1
# anaconda-client==1.7.2
# anaconda-navigator==1.10.0
# anaconda-project==0.8.3
# argcomplete==1.12.3
# argh==0.26.2
# Note: you may need to restart the kernel to use updated packages.argon2-cffi @ file:///C:/ci/argon2-cffi_1596828585465/work
# asn1crypto @ file:///tmp/build/80754af9/asn1crypto_1596577642040/work
# astroid @ file:///C:/ci/astroid_1592487315634/work
# WARNING: Could not generate requirement for distribution -5py 2.10.0 (c:\programdata\anaconda3\lib\site-packages): Parse error at "'-5py==2.'": Expected W:(abcd...)
# WARNING: Could not generate requirement for distribution -rapt 1.11.2 (c:\programdata\anaconda3\lib\site-packages): Parse error at "'-rapt==1'": Expected W:(abcd...)
# ...

# %%
pip list
# Out:
# Package                            Version
# ---------------------------------- -------------------
# -                                  ikit-learn
# -.ikit-learn                       0.23.2
# -0ikit-learn                       0.23.2
# -5py                               2.10.0
# -cikit-learn                       0.23.2
# -ikit-learn                        0.23.2
# -rapt                              1.11.2
# absl-py                            0.13.0
# alabaster                          0.7.12
# alembic                            1.4.1
# anaconda-client                    1.7.2
# anaconda-navigator                 1.10.0
# anaconda-project                   0.8.3
# argcomplete                        1.12.3
# argh                               0.26.2
# argon2-cffi                        20.1.0
# asn1crypto                         1.4.0
# astroid                            2.4.2
# astropy                            4.0.2
# astunparse                         1.6.3
# ...

# %%
import pandas
print(numpy.format_version)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-a33f9c8ad020> in <module>
#       1 import pandas
# ----> 2 print(numpy.format_version)
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\__init__.py in __getattr__(attr)
#     212                 return Tester
#     213             else:
# --> 214                 raise AttributeError("module {!r} has no attribute "
#     215                                      "{!r}".format(__name__, attr))
#     216
#
# AttributeError: module 'numpy' has no attribute 'format_version'

# %%
pip show pickle
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Package(s) not found: pickle

# %%
import pickle
print(pickle.__doc__)
# Out:
# Create portable serialized representations of Python objects.
#
# See module copyreg for a mechanism for registering custom picklers.
# See module pickletools source for extensive comments.
#
# Classes:
#
#     Pickler
#     Unpickler
#
# Functions:
#
#     dump(object, file)
#     dumps(object) -> string
#     load(file) -> object
#     loads(string) -> object
#
# Misc variables:
#
#     __version__
#     format_version
#     compatible_formats
